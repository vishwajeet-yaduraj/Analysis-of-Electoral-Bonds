# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("i1ko9VVHBt (1).csv")

# %%
df.drop('Unnamed: 3', axis=1, inplace=True)

# %%
df_out = df.groupby('Purchaser Name')   # ['Denomination'].sum()
print(df_out)

# %%
req = df_out.sum()
sorted_req = req.sort_values(by = ['Denomination'])

# %%
req[req['Denomination'].max()==req['Denomination']]
# Out:
#                                                                       Date of Purchase  \
# Purchaser Name
# FUTURE GAMING AND HOTEL SERVICES PR  21/Oct/202021/Oct/202021/Oct/202021/Oct/202021...
#
#                                      Denomination
# Purchaser Name
# FUTURE GAMING AND HOTEL SERVICES PR   12080000000

# %%
req[req['Denomination'].min()==req['Denomination']]
# Out:
#                                Date of Purchase  Denomination
# Purchaser Name
# ADWITA FINVEST PRIVATE LIMITED      10/Jan/2022          1000
# ANKUR SINGHAL S O SH ANIL SIN       04/Oct/2023          1000
# ARAVIND S                           10/Jul/2023          1000
# DAMINI NATH                         23/Jan/2023          1000
# KUNAL GUPTA                         10/Jan/2024          1000
# MR. SAMEER BHATIA                   07/Oct/2023          1000
# N RAMAMOORTHY                       07/Apr/2021          1000
# PAWAN AGARWAL                       15/Nov/2022          1000
# POONAM AGARWAL                      20/Oct/2020          1000
# PUNIT DEVENDRABHAI BHANDERI         07/Jul/2023          1000

# %%
sorted_req.tail(50)
# Out:
#                                                                                    Date of Purchase  \
# Purchaser Name
# SHIRDI SAI ELECTRICALS LTD                        11/Jan/202411/Jan/202411/Jan/202411/Jan/202411...
# SEPC POWER PVT LTD OPERATION RETEN                17/Nov/202317/Nov/202317/Nov/202317/Nov/202317...
# MODERN ROAD MAKERS PVT. LTD.                      05/Jan/202205/Jan/202205/Jan/202205/Jan/202205...
# LAXMI CIVIL ENGINEERING SERVICES PR               06/Apr/202306/Apr/202306/Apr/202306/Apr/202306...
# TRANSWAYS EXIM PRIVATE LIMITED                    05/Oct/202105/Oct/202105/Oct/202105/Oct/202105...
# TORRENT PHARMACEUTICALS LTD                       07/Jan/202207/Jan/202207/Jan/202207/Jan/202207...
# SASMAL INFRASTRUCTURE PRIVATE LIMITED             08/Nov/202308/Nov/202308/Nov/202308/Nov/202308...
# RITHWIK PROJECTS PRIVATE LIMITED                  27/Jan/202327/Jan/202327/Jan/202327/Jan/202327...
# ...
